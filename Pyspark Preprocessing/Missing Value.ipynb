# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/pygmy/Projects/Veni/Bisnis_Pintar/HousingData.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
np.random.seed(0)

# %%
missing_values_count = df.isnull().sum()

# %%
missing_values_count
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
#this is actually removing a column with at least 1 null in it
columns_with_na_dropped = df.dropna(axis=0) #axis 1 itu kolom, axis 0 adalah baris
columns_with_na_dropped.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 5  394.12   5.21  28.7

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % df.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 14
#
# Columns with na's dropped: 8

# %%
columns_with_na_dropped
# Out:
#        NOX     RM     DIS  RAD  TAX  PTRATIO       B  MEDV
# 0    0.538  6.575  4.0900    1  296     15.3  396.90  24.0
# 1    0.469  6.421  4.9671    2  242     17.8  396.90  21.6
# 2    0.469  7.185  4.9671    2  242     17.8  392.83  34.7
# 3    0.458  6.998  6.0622    3  222     18.7  394.63  33.4
# 4    0.458  7.147  6.0622    3  222     18.7  396.90  36.2
# 5    0.458  6.430  6.0622    3  222     18.7  394.12  28.7
# 6    0.524  6.012  5.5605    5  311     15.2  395.60  22.9
# 7    0.524  6.172  5.9505    5  311     15.2  396.90  27.1
# 8    0.524  5.631  6.0821    5  311     15.2  386.63  16.5
# 9    0.524  6.004  6.5921    5  311     15.2  386.71  18.9
# 10   0.524  6.377  6.3467    5  311     15.2  392.52  15.0
# 11   0.524  6.009  6.2267    5  311     15.2  396.90  18.9
# 12   0.524  5.889  5.4509    5  311     15.2  390.50  21.7
# 13   0.538  5.949  4.7075    4  307     21.0  396.90  20.4
# 14   0.538  6.096  4.4619    4  307     21.0  380.02  18.2
# ...

# %%
df.mean()
# Out:
# CRIM         3.611874
# ZN          11.211934
# INDUS       11.083992
# CHAS         0.069959
# NOX          0.554695
# RM           6.284634
# AGE         68.518519
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.715432
# MEDV        22.532806
# dtype: float64

# %%
#ISI DENGAN RATA2
sparkdf = df.fillna(df.mean())

# %%
sparkdf = spark.createDataFrame(sparkdf)

# %% [markdown]
# import pandas as pd
# import numpy as np
#
# radioValue=""
#
# if radioValue=='remove':
#     dropna = """+ table_name + """.dropna(axis=1)
#     missingval_"""+ table_name +""" = spark.createDataFrame(dropna)
#     missingval_"""+ table_name +""".createOrReplaceTempView('missingval_"""+ table_name +"""')
#     missingval_"""+ table_name +""".show()
#
# elif radioValue=='average':
#     fillna = """+ table_name +""".fillna("""+table_name +""".mean())
#     missingval_"""+ table_name +""" = spark.createDataFrame(fillna)
#     missingval_"""+ table_name +""".createOrReplaceTempView('missingval_"""+ table_name +"""')
#     missingval_"""+ table_name +""".show()
#
# else:
#     missingval_"""+ table_name +""" = """+ table_name +"""
#     missingval_"""+ table_name +""".createOrReplaceTempView('"""+ table_name +"""')
#     missingval_"""+ table_name +""".show()

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/pygmy/Projects/Veni/Bisnis_Pintar/HousingData.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
missing = df.isnull().sum()

# %%
missing
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
dropna = df.dropna(axis=0)
missingval_tablename = spark.createDataFrame(dropna)

# %%
missingval_tablename.show()
# Out:
# +--------------------+----+-----+----+-------------------+------------------+-----+------+---+---+-------+------+-----+----+
# |                CRIM|  ZN|INDUS|CHAS|                NOX|                RM|  AGE|   DIS|RAD|TAX|PTRATIO|     B|LSTAT|MEDV|
# +--------------------+----+-----+----+-------------------+------------------+-----+------+---+---+-------+------+-----+----+
# |             0.00632|18.0| 2.31| 0.0| 0.5379999999999999|             6.575| 65.2|  4.09|  1|296|   15.3| 396.9| 4.98|24.0|
# |             0.02731| 0.0| 7.07| 0.0|              0.469|             6.421| 78.9|4.9671|  2|242|   17.8| 396.9| 9.14|21.6|
# |             0.02729| 0.0| 7.07| 0.0|              0.469|             7.185| 61.1|4.9671|  2|242|   17.8|392.83| 4.03|34.7|
# |0.032369999999999996| 0.0| 2.18| 0.0|0.45799999999999996| 6.997999999999999| 45.8|6.0622|  3|222|   18.7|394.63| 2.94|33.4|
# ...

# %%
missingval_tablename.show()
# Out:
# +-------------------+------------------+------+---+---+-------+------+----+
# |                NOX|                RM|   DIS|RAD|TAX|PTRATIO|     B|MEDV|
# +-------------------+------------------+------+---+---+-------+------+----+
# | 0.5379999999999999|             6.575|  4.09|  1|296|   15.3| 396.9|24.0|
# |              0.469|             6.421|4.9671|  2|242|   17.8| 396.9|21.6|
# |              0.469|             7.185|4.9671|  2|242|   17.8|392.83|34.7|
# |0.45799999999999996| 6.997999999999999|6.0622|  3|222|   18.7|394.63|33.4|
# |0.45799999999999996|             7.147|6.0622|  3|222|   18.7| 396.9|36.2|
# |0.45799999999999996|              6.43|6.0622|  3|222|   18.7|394.12|28.7|
# |              0.524|6.0120000000000005|5.5605|  5|311|   15.2| 395.6|22.9|
# |              0.524| 6.172000000000001|5.9505|  5|311|   15.2| 396.9|27.1|
# |              0.524|             5.631|6.0821|  5|311|   15.2|386.63|16.5|
# ...

# %%
fillna = df.fillna(df.mean())

# %%
m = spark.createDataFrame(fillna)

# %%
m.createOrReplaceTempView('m')

# %%
m.show()
# Out:
# +--------------------+----+-----+-------------------+-------------------+------------------+-----+------+---+---+-------+------+------------------+----+
# |                CRIM|  ZN|INDUS|               CHAS|                NOX|                RM|  AGE|   DIS|RAD|TAX|PTRATIO|     B|             LSTAT|MEDV|
# +--------------------+----+-----+-------------------+-------------------+------------------+-----+------+---+---+-------+------+------------------+----+
# |             0.00632|18.0| 2.31|                0.0| 0.5379999999999999|             6.575| 65.2|  4.09|  1|296|   15.3| 396.9|              4.98|24.0|
# |             0.02731| 0.0| 7.07|                0.0|              0.469|             6.421| 78.9|4.9671|  2|242|   17.8| 396.9|              9.14|21.6|
# |             0.02729| 0.0| 7.07|                0.0|              0.469|             7.185| 61.1|4.9671|  2|242|   17.8|392.83|              4.03|34.7|
# ...
